# %% [markdown]
# Sources
#
# https://github.com/makcedward/nlpaug
#
# https://github.com/dsfsi/textaugment

# %%
# !pip install deap
# !pip install fasttext
# !pip install nltk
# !pip install nlpaug
# !pip install gensim

# %%
# %cd "/content/drive/MyDrive/project550-main"
# Out:
# /content/drive/MyDrive/project550-main

# %% [markdown]
# **Two types of data augmentation are applied—synonym replacement using WordNet and contextual word substitution using BERT—on both training and test sets. The augmented sentences are saved separately and their semantic similarity with the original sentences is evaluated using cosine similarity.**

# %%
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.sentence as nas

# %%
import random
import numpy as np
import pandas as pd
from sklearn.manifold import TSNE

# %% [markdown]
# **import utils functions**

# %%
from utils import extract_all_sentences, clean_text
from utils_models import *
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %% [markdown]
# **Extract all sentences for each patient and put into a list. all_sentences is 2D list as an output.**

# %%
train_cc = "ADReSS-IS2020-data/train/transcription/cc"
train_cd = "ADReSS-IS2020-data/train/transcription/cd"
test = "ADReSS-IS2020-data-test/test/transcription"
all_sentences_cc = extract_all_sentences(train_cc)
all_sentences_cd = extract_all_sentences(train_cd)
all_sentences_test = extract_all_sentences(test)

# %% [markdown]
# **Apply cleaning step on all_sentences both for training and testing dataset. Output is a 2D list.**

# %%
random.seed(42)
np.random.seed(42)
cleaned_healthy_speech = [
    [clean_text(sentence) for sentence in sentence_list]
    for sentence_list in all_sentences_cc
]

cleaned_dementia_speech = [
    [clean_text(sentence) for sentence in sentence_list]
    for sentence_list in all_sentences_cd
]

cleaned_test_speech = [
    [clean_text(sentence) for sentence in sentence_list]
    for sentence_list in all_sentences_test
]

# %% [markdown]
# **Combine CC and CD to make training dataset**

# %%
cleaned_train_speech = cleaned_healthy_speech + cleaned_dementia_speech

# %% [markdown]
# **1. Synonym Augmentation**

# %%
syn_aug = naw.SynonymAug(aug_src='wordnet')
def sysonym_augment(sentence):
    try:
        result = syn_aug.augment(sentence)
        return result if isinstance(result, list) else [result]
    except Exception as e:
        print(f"Error augmenting sentence: {e}")
        return []

# %%
augmented_train_speech = [sum([sysonym_augment(s) for s in group], []) for group in cleaned_train_speech]
with open("sys_augmented_sentences_train.txt", 'w', encoding='utf-8') as f:
    for sentence_group in augmented_train_speech:
        joined_sentences = ", ".join(sentence_group)
        f.write(f"[{joined_sentences}]\n")

# %%
augmented_test_speech = [sum([sysonym_augment(s) for s in group], []) for group in cleaned_test_speech]
with open("sys_augmented_sentences_test.txt", 'w', encoding='utf-8') as f:
    for sentence_group in augmented_test_speech:
        joined_sentences = ", ".join(sentence_group)
        f.write(f"[{joined_sentences}]\n")

# %% [markdown]
# **2. Contextual Augmentation**

# %%
cont_aug = naw.ContextualWordEmbsAug(model_path='bert-base-uncased', action="substitute")
def contextual_augment(sentence):
    try:
        result = cont_aug.augment(sentence)
        return result if isinstance(result, list) else [result]
    except Exception as e:
        print(f"Error augmenting sentence: {e}")
        return []
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
augmented_train_speech_cont = [sum([contextual_augment(s) for s in group], []) for group in cleaned_train_speech]
with open("cont_augmented_sentences_train.txt", 'w', encoding='utf-8') as f:
    for sentence_group in augmented_train_speech_cont:
        joined_sentences = ", ".join(sentence_group)
        f.write(f"[{joined_sentences}]\n")

# %%
augmented_test_speech_cont = [sum([contextual_augment(s) for s in group], []) for group in cleaned_test_speech]
with open("cont_augmented_sentences_test.txt", 'w', encoding='utf-8') as f:
    for sentence_group in augmented_test_speech_cont:
        joined_sentences = ", ".join(sentence_group)
        f.write(f"[{joined_sentences}]\n")

# %% [markdown]
# **Check The Similarity of Augmented and original data**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def cosine_sim(sentence1, sentence2):
    vectorizer = TfidfVectorizer(token_pattern=r"(?u)\b\w+\b", analyzer='char').fit_transform([sentence1, sentence2])
    cosine_sim_matrix = cosine_similarity(vectorizer[0:1], vectorizer[1:2])
    return cosine_sim_matrix[0][0]

# %%
flat_clean_train = [s for group in cleaned_train_speech for s in group]

with open('cont_augmented_sentences_train.txt', encoding='utf-8') as f:
    aug_train_sentences = [line.strip().strip('[]') for line in f.readlines()]
    flat_aug_train = [s.strip() for group in aug_train_sentences for s in group.split(',') if s.strip()]

for clean, aug in zip(flat_clean_train, flat_aug_train):
    sim = cosine_sim(clean, aug)
    print(f"Clean: {clean}\nAugmented: {aug}\nCosine Similarity: {sim:.4f}\n{'-'*50}")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_extraction/text.py:547: UserWarning: The parameter 'token_pattern' will not be used since 'analyzer' != 'word'
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# Clean: plate cup gram
# Augmented: could see old hedge
# Cosine Similarity: 0.3447
# --------------------------------------------------
# Clean: outside see outside hedge
# Augmented: outside cup of jar you think
# Cosine Similarity: 0.6214
# --------------------------------------------------
# Clean: outside cup cook jar would hata
# Augmented: the counter kitchen
# Cosine Similarity: 0.5383
# --------------------------------------------------
# Clean: call counter kitchen
# Augmented: curtain dance
# Cosine Similarity: 0.7180
# --------------------------------------------------
# Clean: curtain gram
# Augmented: thomas gram
# Cosine Similarity: 0.5824
# --------------------------------------------------
# Clean: window gram
# Augmented: 2007 see go 2018
# Cosine Similarity: 0.1447
# --------------------------------------------------
# Clean: action see go etc
# Augmented: okay when
# Cosine Similarity: 0.4117
# --------------------------------------------------
# Clean: okay etc
# Augmented: c
# Cosine Similarity: 0.2597
# --------------------------------------------------
# Clean: kitchen
# Augmented: little mountain climb cook...
# Cosine Similarity: 0.3998
# --------------------------------------------------
# Clean: little boy climb cook jar
# Augmented: mother would turn
# Cosine Similarity: 0.4973
# --------------------------------------------------
# Clean: mother back turn
# Augmented: stand sink to house
# Cosine Similarity: 0.5122
# --------------------------------------------------
# Clean: stand sink wash dish
# Augmented: i mean window cause sink run
# Cosine Similarity: 0.6755
# --------------------------------------------------
# Clean: probably look window cause sink run
# Augmented: spinal tap little brother go fall
# Cosine Similarity: 0.6052
# --------------------------------------------------
# Clean: stool tap little boy go fall
# Augmented: window covers and
# Cosine Similarity: 0.3025
# --------------------------------------------------
# Clean: window open xxx
# Augmented: water run electric drum
# Cosine Similarity: 0.2517
# --------------------------------------------------
# Clean: water run sink xxx
# Augmented: see ॥
# Cosine Similarity: 0.2828
# --------------------------------------------------
# Clean: see etc
# Augmented: mother dry wrong
# Cosine Similarity: 0.2300
# --------------------------------------------------
# Clean: mother dry dish
# Augmented: 5 etc
# Cosine Similarity: 0.2412
# --------------------------------------------------
# Clean: hm etc
# Augmented: v etc
# Cosine Similarity: 0.5803
# --------------------------------------------------
# Clean: okay etc
# Augmented: in mother dry to
# Cosine Similarity: 0.4490
# --------------------------------------------------
# Clean: well mother dry dish
# Augmented: sink ॥
# Cosine Similarity: 0.2154
# --------------------------------------------------
# Clean: sink overflow
# Augmented: jack could reach cook
# Cosine Similarity: 0.3603
# --------------------------------------------------
# Clean: little girl reach cook
# Augmented: brother take out the cook 。
# Cosine Similarity: 0.6704
# --------------------------------------------------
# Clean: brother take colony outdo cook jar
# Augmented: stool go f u...
# Cosine Similarity: 0.5071
# --------------------------------------------------
# Clean: stool go f knock floor
# Augmented: late fall floor 2
# Cosine Similarity: 0.6294
# --------------------------------------------------
# Clean: go fall floor stool
# Augmented: gravity...
# Cosine Similarity: 0.0716
# --------------------------------------------------
# Clean: gravity etc
# Augmented: whatever ॥
# Cosine Similarity: 0.5037
# --------------------------------------------------
# Clean: whatever etc
# Augmented: curtain blowing [UNK]
# Cosine Similarity: 0.1922
# --------------------------------------------------
# Clean: curtain blowing think
# Augmented: 1 etc
# Cosine Similarity: 0.2365
# --------------------------------------------------
# Clean: see etc
# Augmented: do take colony water jar give away
# Cosine Similarity: 0.3847
# --------------------------------------------------
# Clean: boy take colony cook jar give one
# Augmented: also see stool
# Cosine Similarity: 0.5621
# --------------------------------------------------
# Clean: also fall stool
# Augmented: mother daughter dish
# Cosine Similarity: 0.2244
# --------------------------------------------------
# Clean: mother wash dish
# Augmented: let me and
# Cosine Similarity: 0.3837
# --------------------------------------------------
# Clean: let sink overflow
# Augmented: fourth floor
# Cosine Similarity: 0.5199
# --------------------------------------------------
# Clean: get floor
# Augmented: do nothing etc
# Cosine Similarity: 0.4909
# --------------------------------------------------
# Clean: see nothing etc
# Augmented: and say quiet name
# Cosine Similarity: 0.5212
# --------------------------------------------------
# Clean: girl say quiet count
# Augmented: know mother get lost like
# Cosine Similarity: 0.6252
# --------------------------------------------------
# Clean: know mother get stand water
# Augmented: think online etc
# Cosine Similarity: 0.5880
# --------------------------------------------------
# Clean: think important etc
# Augmented: ... etc
# Cosine Similarity: 0.2386
# --------------------------------------------------
# Clean: see etc
# Augmented: 2nd etc
# Cosine Similarity: 0.5094
# --------------------------------------------------
# Clean: miss etc
# Augmented: UNK] picture xxx [UNK]
# Cosine Similarity: 0.2052
# --------------------------------------------------
# Clean: look picture xxx etc
# Augmented: oh ha etc
# Cosine Similarity: 0.4480
# --------------------------------------------------
# Clean: oh okay etc
# Augmented: miss boy stool get same
# Cosine Similarity: 0.5204
# --------------------------------------------------
# Clean: one boy stool get colony
# Augmented: so dry means red fauces fill
# Cosine Similarity: 0.5169
# --------------------------------------------------
# Clean: mother dry dish sink fauces fill
# Augmented: action toward
# Cosine Similarity: 0.4382
# --------------------------------------------------
# Clean: action etc
# Augmented: let and etc
# Cosine Similarity: 0.6902
# --------------------------------------------------
# Clean: let see etc
# Augmented: w etc
# Cosine Similarity: 0.6843
# --------------------------------------------------
# Clean: okay etc
# Augmented: many places mother wash house sink
# Cosine Similarity: 0.5312
# --------------------------------------------------
# Clean: many dish mother wash dish sink
# Augmented: dry left side ।
# Cosine Similarity: 0.5372
# --------------------------------------------------
# Clean: dry already side look
# Augmented: water creek
# Cosine Similarity: 0.4161
# --------------------------------------------------
# Clean: water floor
# Augmented: then outside mother ।
# Cosine Similarity: 0.4707
# --------------------------------------------------
# Clean: garden outside mother pay
# Augmented: stool of
# Cosine Similarity: 0.3463
# --------------------------------------------------
# Clean: stool tap
# Augmented: cook bottle lid open
# Cosine Similarity: 0.6350
# --------------------------------------------------
# Clean: cook jar door open
# Augmented: little little things come
# Cosine Similarity: 0.2272
# --------------------------------------------------
# Clean: may little breeze come
# Augmented: little i say name
# Cosine Similarity: 0.7495
# --------------------------------------------------
# Clean: little girl say finger
# Augmented: but tell mother give o
# Cosine Similarity: 0.6637
# --------------------------------------------------
# Clean: wo tell mother give cook
# Augmented: kitchen number two
# Cosine Similarity: 0.6430
# --------------------------------------------------
# Clean: kitchen cup two
# Augmented: by step mommy probably
# Cosine Similarity: 0.2617
# --------------------------------------------------
# Clean: mother step water probably
# Augmented: okay so
# Cosine Similarity: 0.3554
# --------------------------------------------------
# Clean: okay etc
# Augmented: little kids get steady
# Cosine Similarity: 0.4905
# --------------------------------------------------
# Clean: little boy get stand
# Augmented: get and share cook do
# Cosine Similarity: 0.6139
# --------------------------------------------------
# Clean: get cook share cook little
# Augmented: ... etc
# Cosine Similarity: 0.2607
# --------------------------------------------------
# Clean: k etc
# Augmented: instruction good
# Cosine Similarity: 0.2157
# --------------------------------------------------
# Clean: instruction etc
# Augmented: give additional detail measurements etc
# Cosine Similarity: 0.6140
# --------------------------------------------------
# Clean: give many detail like etc
# Augmented: and etc
# Cosine Similarity: 0.6397
# --------------------------------------------------
# Clean: action etc
# Augmented: [UNK]
# Cosine Similarity: 0.0649
# --------------------------------------------------
# Clean: etc
# Augmented: not okay etc
# Cosine Similarity: 0.4237
# --------------------------------------------------
# Clean: oh okay etc
# Augmented: cupboard door closed
# Cosine Similarity: 0.4691
# --------------------------------------------------
# Clean: cupboard door open
# Augmented: not crooked
# Cosine Similarity: 0.7205
# --------------------------------------------------
# Clean: stool crooked
# Augmented: shower splash floor
# Cosine Similarity: 0.5982
# --------------------------------------------------
# Clean: water splash floor
# Augmented: mother my mother
# Cosine Similarity: 0.4073
# --------------------------------------------------
# Clean: mother assume mother
# Augmented: dry effective
# Cosine Similarity: 0.3373
# --------------------------------------------------
# Clean: dry dish
# Augmented: occasional overflow
# Cosine Similarity: 0.1208
# --------------------------------------------------
# Clean: sink overflow
# Augmented: cup won
# Cosine Similarity: 0.3323
# --------------------------------------------------
# Clean: cup saucer
# Augmented: window open see it one
# Cosine Similarity: 0.2171
# --------------------------------------------------
# Clean: window open see lawn outside
# Augmented: indian summertime
# Cosine Similarity: 0.4851
# --------------------------------------------------
# Clean: must summertime
# Augmented: short short shorter
# Cosine Similarity: 0.3110
# --------------------------------------------------
# Clean: short short sleeve
# Augmented: wear to
# Cosine Similarity: 0.4975
# --------------------------------------------------
# Clean: wear apron
# Augmented: okay yeah
# Cosine Similarity: 0.3533
# --------------------------------------------------
# Clean: okay etc
# Augmented: action ।
# Cosine Similarity: 0.4576
# --------------------------------------------------
# Clean: action etc
# Augmented: w etc
# Cosine Similarity: 0.5801
# --------------------------------------------------
# Clean: alright etc
# Augmented: lady iron dish
# Cosine Similarity: 0.3407
# --------------------------------------------------
# Clean: lady dry dish
# Augmented: to stand line action
# Cosine Similarity: 0.3401
# --------------------------------------------------
# Clean: boy stand stool action
# Augmented: girl on hold reach cook
# Cosine Similarity: 0.5742
# --------------------------------------------------
# Clean: girl hand raise reach cook
# Augmented: high sink
# Cosine Similarity: 0.4646
# --------------------------------------------------
# Clean: action sink
# Augmented: net flow
# Cosine Similarity: 0.3035
# --------------------------------------------------
# Clean: water flow
# Augmented: apparently distract you and
# Cosine Similarity: 0.4069
# --------------------------------------------------
# Clean: apparently distract daydream ca
# Augmented: action drawing
# Cosine Similarity: 0.6039
# --------------------------------------------------
# Clean: action etc
# Augmented: delayed action etc
# Cosine Similarity: 0.7620
# --------------------------------------------------
# Clean: enough action etc
# Augmented: seth sent mother dish
# Cosine Similarity: 0.5486
# --------------------------------------------------
# Clean: well see mother dish
# Augmented: sink water comes up gram
# Cosine Similarity: 0.5899
# --------------------------------------------------
# Clean: sink water run sink gram
# Augmented: boy take the cook jar when
# Cosine Similarity: 0.5388
# --------------------------------------------------
# Clean: boy take colony cook jar l
# Augmented: stool ॥
# Cosine Similarity: 0.5538
# --------------------------------------------------
# Clean: stool fall
# Augmented: yeah...
# Cosine Similarity: 0.0342
# --------------------------------------------------
# Clean: yeah etc
# Augmented: hand pas que du
# Cosine Similarity: 0.3577
# --------------------------------------------------
# Clean: hand pas cook quiet
# Augmented: h
# Cosine Similarity: 0.1333
# --------------------------------------------------
# Clean: mother
# Augmented: kitchen sink
# Cosine Similarity: 0.1758
# --------------------------------------------------
# Clean: dish sink
# Augmented: yeah... etc
# Cosine Similarity: 0.0688
# --------------------------------------------------
# Clean: yeah okay etc
# Augmented: 13 etc
# Cosine Similarity: 0.3778
# --------------------------------------------------
# Clean: hm etc
# Augmented: my lip gram
# Cosine Similarity: 0.2721
# --------------------------------------------------
# Clean: touch lip gram
# Augmented: raise a gram
# Cosine Similarity: 0.5132
# --------------------------------------------------
# Clean: raise arm gram
# Augmented: mean ॥
# Cosine Similarity: 0.4393
# --------------------------------------------------
# Clean: mean etc
# Augmented: my reach toward gram
# Cosine Similarity: 0.4901
# --------------------------------------------------
# Clean: lea reach cook gram
# Augmented: a cook gram
# Cosine Similarity: 0.8329
# --------------------------------------------------
# Clean: hand cook gram
# Augmented: slip stool to
# Cosine Similarity: 0.2785
# --------------------------------------------------
# Clean: slip stool gram
# Augmented: stool fall from
# Cosine Similarity: 0.7314
# --------------------------------------------------
# Clean: stool fall gram
# Augmented: wipe her gram
# Cosine Similarity: 0.2959
# --------------------------------------------------
# Clean: wipe dish gram
# Augmented: water or gram
# Cosine Similarity: 0.5124
# --------------------------------------------------
# Clean: water run gram
# Augmented: gram and gram
# Cosine Similarity: 0.7517
# --------------------------------------------------
# Clean: water overflow gram
# Augmented: breeze ।
# Cosine Similarity: 0.3688
# --------------------------------------------------
# Clean: breeze gram
# Augmented: physical action etc
# Cosine Similarity: 0.1800
# --------------------------------------------------
# Clean: know action etc
# Augmented: sweet water gram
# Cosine Similarity: 0.3872
# --------------------------------------------------
# Clean: step water gram
# Augmented: guess by
# Cosine Similarity: 0.3093
# --------------------------------------------------
# Clean: guess etc
# Augmented: w etc
# Cosine Similarity: 0.4711
# --------------------------------------------------
# Clean: hm etc
# Augmented: run then run floor
# Cosine Similarity: 0.2594
# --------------------------------------------------
# Clean: well water run floor
# Augmented: low stool under tilt
# Cosine Similarity: 0.7753
# --------------------------------------------------
# Clean: chair stool r tilt
# Augmented: green cook jar
# Cosine Similarity: 0.3898
# --------------------------------------------------
# Clean: boy cook jar
# Augmented: sister susan cook
# Cosine Similarity: 0.3998
# --------------------------------------------------
# Clean: sister reach cook
# Augmented: mother house dish
# Cosine Similarity: 0.6689
# --------------------------------------------------
# Clean: mother dry dish
# Augmented: want action want information... etc
# Cosine Similarity: 0.3008
# --------------------------------------------------
# Clean: want action want anything see etc
# Augmented: okay ।
# Cosine Similarity: 0.2836
# --------------------------------------------------
# Clean: okay etc
# Augmented: hm o
# Cosine Similarity: 0.2203
# --------------------------------------------------
# Clean: hm etc
# Augmented: okay...
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: okay etc
# Augmented: mother makes a sink
# Cosine Similarity: 0.5103
# --------------------------------------------------
# Clean: mother wipe dish sink
# Augmented: • overflow ॥
# Cosine Similarity: 0.3351
# --------------------------------------------------
# Clean: water overflow sink
# Augmented: youngster fall north of cook station
# Cosine Similarity: 0.7091
# --------------------------------------------------
# Clean: youngster fall stool reach cook jar
# Augmented: short girl helped hand grab cook let
# Cosine Similarity: 0.8347
# --------------------------------------------------
# Clean: little girl hold hand grab cook outdo
# Augmented: window close open open make action
# Cosine Similarity: 0.6671
# --------------------------------------------------
# Clean: window appear open ca make action
# Augmented: via
# Cosine Similarity: 0.2653
# --------------------------------------------------
# Clean: etc
# Augmented: well little i say yes brother
# Cosine Similarity: 0.2891
# --------------------------------------------------
# Clean: well little girl say quiet brother
# Augmented: 2005 cook jar fall final
# Cosine Similarity: 0.4581
# --------------------------------------------------
# Clean: brother cook jar fall chair
# Augmented: not oblivious
# Cosine Similarity: 0.3714
# --------------------------------------------------
# Clean: mother oblivious
# Augmented: wash up or come outdo bathroom
# Cosine Similarity: 0.6595
# --------------------------------------------------
# Clean: wash dish water come outdo sink
# Augmented: and think etc
# Cosine Similarity: 0.6380
# --------------------------------------------------
# Clean: know think etc
# Augmented: also see etc
# Cosine Similarity: 0.3643
# --------------------------------------------------
# Clean: let see etc
# Augmented: anything outside ।
# Cosine Similarity: 0.3746
# --------------------------------------------------
# Clean: anything outside etc
# Augmented: david bush
# Cosine Similarity: 0.3627
# --------------------------------------------------
# Clean: guess bush
# Augmented: 14 etc
# Cosine Similarity: 0.1096
# --------------------------------------------------
# Clean: know etc
# Augmented: 1 etc
# Cosine Similarity: 0.4743
# --------------------------------------------------
# Clean: okay etc
# Augmented: 40 etc
# Cosine Similarity: 0.4112
# --------------------------------------------------
# Clean: nothing etc
# Augmented: ... etc
# Cosine Similarity: 0.2244
# --------------------------------------------------
# Clean: okay etc
# Augmented: dish from
# Cosine Similarity: 0.1351
# --------------------------------------------------
# Clean: dish okay
# Augmented: let see as
# Cosine Similarity: 0.2340
# --------------------------------------------------
# Clean: let see etc
# Augmented: shoe...
# Cosine Similarity: 0.1693
# --------------------------------------------------
# Clean: shoe etc
# Augmented: sock records
# Cosine Similarity: 0.5120
# --------------------------------------------------
# Clean: sock alright
# Augmented: know...
# Cosine Similarity: 0.0880
# --------------------------------------------------
# Clean: know etc
# Augmented: if take him outdo cook jar...
# Cosine Similarity: 0.4793
# --------------------------------------------------
# Clean: boy take colony outdo cook jar gram
# Augmented: stool tree
# Cosine Similarity: 0.5741
# --------------------------------------------------
# Clean: stool fall
# Augmented: little lost reach
# Cosine Similarity: 0.6469
# --------------------------------------------------
# Clean: little girl reach
# Augmented: water lily f chorus
# Cosine Similarity: 0.7265
# --------------------------------------------------
# Clean: water run f fauces
# Augmented: beside a sink
# Cosine Similarity: 0.4078
# --------------------------------------------------
# Clean: water overflow sink
# Augmented: b and g dish ka dish gram
# Cosine Similarity: 0.3561
# --------------------------------------------------
# Clean: woman wash g dish dry dish gram
# Augmented: to indicate xxx by action
# Cosine Similarity: 0.4181
# --------------------------------------------------
# Clean: nothing indicate xxx see action
# Augmented: 9 etc
# Cosine Similarity: 0.4110
# --------------------------------------------------
# Clean: ready etc
# Augmented: some under overflow
# Cosine Similarity: 0.3968
# --------------------------------------------------
# Clean: well sink overflow
# Augmented: mother of water drink jerk
# Cosine Similarity: 0.5273
# --------------------------------------------------
# Clean: mother stand water like jerk
# Augmented: wipe dish food for jerk
# Cosine Similarity: 0.6291
# --------------------------------------------------
# Clean: wipe dish also like jerk
# Augmented: boy do get
# Cosine Similarity: 0.3692
# --------------------------------------------------
# Clean: boy try get
# Augmented: a hand finger
# Cosine Similarity: 0.2442
# --------------------------------------------------
# Clean: sister hand finger
# Augmented: b
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean:
# Augmented: let one know...
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: quiet
# Augmented: joseph cook
# Cosine Similarity: 0.0587
# --------------------------------------------------
# Clean: let mother know g
# Augmented: moment go like hail ।
# Cosine Similarity: 0.7715
# --------------------------------------------------
# Clean: hand cook
# Augmented: mother reason does flow is
# Cosine Similarity: 0.4653
# --------------------------------------------------
# Clean: moment go like total catastrophe
# Augmented: look at
# Cosine Similarity: 0.7229
# --------------------------------------------------
# Clean: mother reason water flow sink
# Augmented: see anything t
# Cosine Similarity: 0.5890
# --------------------------------------------------
# Clean: look window
# Augmented: unless ।
# Cosine Similarity: 0.1243
# --------------------------------------------------
# Clean: see anything go
# Augmented: or presume to pudding
# Cosine Similarity: 0.5005
# --------------------------------------------------
# Clean: unless etc
# Augmented: told stool...
# Cosine Similarity: 0.2225
# --------------------------------------------------
# Clean: bush presume plum pudding
# Augmented: with a real chaos make
# Cosine Similarity: 0.3171
# --------------------------------------------------
# Clean: told stool go
# Augmented: cook one full
# Cosine Similarity: 0.6054
# --------------------------------------------------
# Clean: moment go real chaos make
# Augmented: 3 cook jar
# Cosine Similarity: 0.5451
# --------------------------------------------------
# Clean: cook jar full
# Augmented: c
# Cosine Similarity: 0.1654
# --------------------------------------------------
# Clean: lid cook jar
# Augmented: want tell you for
# Cosine Similarity: 0.4922
# --------------------------------------------------
# Clean: etc
# Augmented: every door swung and
# Cosine Similarity: 0.1096
# --------------------------------------------------
# Clean: want tell thing etc
# Augmented: all fall gram
# Cosine Similarity: 0.3581
# --------------------------------------------------
# Clean: cabinet door swung open
# Augmented: guess game etc
# Cosine Similarity: 0.4725
# --------------------------------------------------
# Clean: stool fall gram
# Augmented: terrible crash bloody
# Cosine Similarity: 0.5446
# --------------------------------------------------
# Clean: guess told etc
# Augmented: and...
# Cosine Similarity: 0.0322
# --------------------------------------------------
# Clean: terrible crash gram
# Augmented: you know their behind
# Cosine Similarity: 0.4194
# --------------------------------------------------
# Clean: mother daydream
# Augmented: so important sometimes too etc
# Cosine Similarity: 0.4980
# --------------------------------------------------
# Clean: even know go behind
# Augmented: seem of etc
# Cosine Similarity: 0.4667
# --------------------------------------------------
# Clean: think important sometimes typical etc
# Augmented: railway colony
# Cosine Similarity: 0.3916
# --------------------------------------------------
# Clean: seem see etc
# Augmented: mid fall
# Cosine Similarity: 0.0874
# --------------------------------------------------
# Clean: kiss colony
# Augmented: the fresh water also dry dish
# Cosine Similarity: 0.3464
# --------------------------------------------------
# Clean: stool fall
# Augmented: wind might work before
# Cosine Similarity: 0.2160
# --------------------------------------------------
# Clean: mother spell water also dry dish
# Augmented: hot run
# Cosine Similarity: 0.4185
# --------------------------------------------------
# Clean: wind might blowing curtain
# Augmented: nobody heard anything go outside etc
# Cosine Similarity: 0.6739
# --------------------------------------------------
# Clean: water run
# Augmented: guess this etc
# Cosine Similarity: 0.2666
# --------------------------------------------------
# Clean: ca tell anything go outside etc
# Augmented: x etc
# Cosine Similarity: 0.5429
# --------------------------------------------------
# Clean: guess see etc
# Augmented: floor run floor
# Cosine Similarity: 0.0758
# --------------------------------------------------
# Clean: many etc
# Augmented: i take colony over to cook jar
# Cosine Similarity: 0.4378
# --------------------------------------------------
# Clean: water run floor
# Augmented: we fall open
# Cosine Similarity: 0.5377
# --------------------------------------------------
# Clean: boy take colony cook outdo cook jar
# Augmented: girl company cook
# Cosine Similarity: 0.7731
# --------------------------------------------------
# Clean: stool fall open
# Augmented: clean wipe fire xxx
# Cosine Similarity: 0.3435
# --------------------------------------------------
# Clean: girl ask cook
# Augmented: 8 etc
# Cosine Similarity: 0.1865
# --------------------------------------------------
# Clean: wife wipe dish xxx
# Augmented: ... etc
# Cosine Similarity: 0.1260
# --------------------------------------------------
# Clean: guess etc
# Augmented: boy who reach colony with
# Cosine Similarity: 0.2083
# --------------------------------------------------
# Clean: begin etc
# Augmented: 3 fall
# Cosine Similarity: 0.0570
# --------------------------------------------------
# Clean: boy get reach colony gram
# Augmented: first reach colony
# Cosine Similarity: 0.7627
# --------------------------------------------------
# Clean: stool fall
# Augmented: woman fire burns gram
# Cosine Similarity: 0.2180
# --------------------------------------------------
# Clean: sister reach colony
# Augmented: everybody run
# Cosine Similarity: 0.4743
# --------------------------------------------------
# Clean: woman wipe dish gram
# Augmented: curtain was little bit like gram
# Cosine Similarity: 0.5924
# --------------------------------------------------
# Clean: sink run
# Augmented: a step a toe
# Cosine Similarity: 0.1545
# --------------------------------------------------
# Clean: curtain blowing little bit much gram
# Augmented: bad girl tell
# Cosine Similarity: 0.6995
# --------------------------------------------------
# Clean: boy step one toe
# Augmented: q...
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: little girl tell
# Augmented: and mummy see
# Cosine Similarity: 0.1398
# --------------------------------------------------
# Clean: q quiet
# Augmented: 4 etc
# Cosine Similarity: 0.2953
# --------------------------------------------------
# Clean: let mummy see
# Augmented: well for him etc
# Cosine Similarity: 0.5743
# --------------------------------------------------
# Clean: yeah etc
# Augmented: boy do se outdo cook ।
# Cosine Similarity: 0.2664
# --------------------------------------------------
# Clean: well let see etc
# Augmented: bad girl laugh
# Cosine Similarity: 0.2230
# --------------------------------------------------
# Clean: boy take colony outdo cook jar
# Augmented: boy fall...
# Cosine Similarity: 0.3241
# --------------------------------------------------
# Clean: little girl laugh
# Augmented: mother wash ।
# Cosine Similarity: 0.3002
# --------------------------------------------------
# Clean: boy fall stool
# Augmented: water [UNK]
# Cosine Similarity: 0.1312
# --------------------------------------------------
# Clean: mother wash dish
# Augmented: see whether yer blowing
# Cosine Similarity: 0.6247
# --------------------------------------------------
# Clean: water run
# Augmented: start...
# Cosine Similarity: 0.2473
# --------------------------------------------------
# Clean: know whether wind blowing
# Augmented: ...
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: start girl
# Augmented: please cook gram
# Cosine Similarity: 0.3467
# --------------------------------------------------
# Clean: go
# Augmented: of brother house colony old jar
# Cosine Similarity: 0.2854
# --------------------------------------------------
# Clean: steal cook gram
# Augmented: get on
# Cosine Similarity: 0.4779
# --------------------------------------------------
# Clean: brother brother take colony outdo jar
# Augmented: skin in one
# Cosine Similarity: 0.3293
# --------------------------------------------------
# Clean: get careless
# Augmented: level g one
# Cosine Similarity: 0.5428
# --------------------------------------------------
# Clean: skin g one
# Augmented: meantime all g it fall
# Cosine Similarity: 0.3777
# --------------------------------------------------
# Clean: hand g one
# Augmented: his provides g much attention
# Cosine Similarity: 0.5906
# --------------------------------------------------
# Clean: meantime get g reading fall
# Augmented: look a window
# Cosine Similarity: 0.2872
# --------------------------------------------------
# Clean: mother pain g much attention
# Augmented: look window view my sink run
# Cosine Similarity: 0.5005
# --------------------------------------------------
# Clean: look g window
# Augmented: else...
# Cosine Similarity: 0.0280
# --------------------------------------------------
# Clean: look window let g sink run
# Augmented: you look alright
# Cosine Similarity: 0.6381
# --------------------------------------------------
# Clean: else etc
# Augmented: and
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: outside look alright
# Augmented: her dry dish
# Cosine Similarity: 0.4141
# --------------------------------------------------
# Clean: etc
# Augmented: me cup plate and
# Cosine Similarity: 0.3284
# --------------------------------------------------
# Clean: dry dry dish
# Augmented: well say you g... run before
# Cosine Similarity: 0.3145
# --------------------------------------------------
# Clean: two cup plate table
# Augmented: ... boy etc
# Cosine Similarity: 0.3598
# --------------------------------------------------
# Clean: well say let g water run sink
# Augmented: angle control
# Cosine Similarity: 0.5468
# --------------------------------------------------
# Clean: oh boy etc
# Augmented: sort of see else etc
# Cosine Similarity: 0.5662
# --------------------------------------------------
# Clean: angle incomplete
# Augmented: let be etc
# Cosine Similarity: 0.5843
# --------------------------------------------------
# Clean: hm let see else etc
# Augmented: but plate two in two cup
# Cosine Similarity: 0.4744
# --------------------------------------------------
# Clean: let see etc
# Augmented: only... let our water run sink
# Cosine Similarity: 0.4370
# --------------------------------------------------
# Clean: ta plate two say two cup
# Augmented: 2 etc
# Cosine Similarity: 0.4682
# --------------------------------------------------
# Clean: oh say let g water run sink
# Augmented: seem her window
# Cosine Similarity: 0.6181
# --------------------------------------------------
# Clean: yes etc
# Augmented: bout suspended
# Cosine Similarity: 0.4164
# --------------------------------------------------
# Clean: seem look window
# Augmented: alright ॥
# Cosine Similarity: 0.1476
# --------------------------------------------------
# Clean: bout etc
# Augmented: little children in reach get
# Cosine Similarity: 0.4240
# --------------------------------------------------
# Clean: alright etc
# Augmented: place stool stand stool with
# Cosine Similarity: 0.5268
# --------------------------------------------------
# Clean: little boy girl reach get
# Augmented: hawaii colony
# Cosine Similarity: 0.4208
# --------------------------------------------------
# Clean: boy stool stand stool donna
# Augmented: mother r back u o
# Cosine Similarity: 0.4760
# --------------------------------------------------
# Clean: reach colony
# Augmented: he played attention
# Cosine Similarity: 0.4391
# --------------------------------------------------
# Clean: mother r back th em
# Augmented: 3rd place
# Cosine Similarity: 0.3733
# --------------------------------------------------
# Clean: see played attention
# Augmented: window very nice garden close back
# Cosine Similarity: 0.5839
# --------------------------------------------------
# Clean: run place
# Augmented: olive dish
# Cosine Similarity: 0.1708
# --------------------------------------------------
# Clean: window open nice garden garage back
# Augmented: ॥
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: dry dish
# Augmented: dress ।
# Cosine Similarity: 0.5043
# --------------------------------------------------
# Clean: apron
# Augmented: just nice this is pretty nice curtain
# Cosine Similarity: 0.1804
# --------------------------------------------------
# Clean: dress sleepless
# Augmented: jar cook oven open
# Cosine Similarity: 0.1831
# --------------------------------------------------
# Clean: pretty nice kitchen like pretty nice curtain
# Augmented: used to couple plate better
# Cosine Similarity: 0.6566
# --------------------------------------------------
# Clean: jar cook jar lid
# Augmented: party girl sock up shoes dress long
# Cosine Similarity: 0.5402
# --------------------------------------------------
# Clean: couple cup couple plate better
# Augmented: boy short short so so
# Cosine Similarity: 0.2829
# --------------------------------------------------
# Clean: little girl sock shoe short dress long
# Augmented: more bloom outside to
# Cosine Similarity: 0.6995
# --------------------------------------------------
# Clean: boy short short sleeve shirt
# Augmented: we pour... sink
# Cosine Similarity: 0.3573
# --------------------------------------------------
# Clean: tree bloom outside flower
# Augmented: personal wash dish
# Cosine Similarity: 0.4589
# --------------------------------------------------
# Clean: water pour outdo sink
# Augmented: the stool can reach
# Cosine Similarity: 0.5773
# --------------------------------------------------
# Clean: woman wash dish
# Augmented: right hand but left almost finger make
# Cosine Similarity: 0.4845
# --------------------------------------------------
# Clean: child stool fall reach
# Augmented: mother wa foot water supply...
# Cosine Similarity: 0.5329
# --------------------------------------------------
# Clean: right hand look like almost try make
# Augmented: window and
# Cosine Similarity: 0.3285
# --------------------------------------------------
# Clean: mother wa foot water pour floor
# Augmented: see yard ॥
# Cosine Similarity: 0.3696
# --------------------------------------------------
# Clean: window open
# Augmented: milk cup sink
# Cosine Similarity: 0.2568
# --------------------------------------------------
# Clean: see yard outside
# Augmented: gently pull back covered window
# Cosine Similarity: 0.5401
# --------------------------------------------------
# Clean: dish cup sink
# Augmented: cupboard door hallway
# Cosine Similarity: 0.2240
# --------------------------------------------------
# Clean: curtain pull back see window
# Augmented: cocktail dress
# Cosine Similarity: 0.6496
# --------------------------------------------------
# Clean: cupboard door open
# Augmented: nondescript vehicles with
# Cosine Similarity: 0.3858
# --------------------------------------------------
# Clean: fully dress
# Augmented: woman will open little...
# Cosine Similarity: 0.2776
# --------------------------------------------------
# Clean: nondescript expression face
# Augmented: own mouth... little bit
# Cosine Similarity: 0.3184
# --------------------------------------------------
# Clean: woman mouth open little bit
# Augmented: t
# Cosine Similarity: 0.3702
# --------------------------------------------------
# Clean: one mouth open little bit
# Augmented: start after
# Cosine Similarity: 0.3565
# --------------------------------------------------
# Clean: etc
# Augmented: boy was
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: start etc
# Augmented: hot tap
# Cosine Similarity: 0.5328
# --------------------------------------------------
# Clean: boy stool
# Augmented: boy of the outdo jar
# Cosine Similarity: 0.6623
# --------------------------------------------------
# Clean: stool tap
# Augmented: wide open
# Cosine Similarity: 0.2072
# --------------------------------------------------
# Clean: boy take colony outdo jar
# Augmented: girl wil y g his mouth also
# Cosine Similarity: 0.5401
# --------------------------------------------------
# Clean: cupboard open
# Augmented: mother wash [UNK]
# Cosine Similarity: 0.3273
# --------------------------------------------------
# Clean: girl say put g finger mouth also
# Augmented: water is hit onto floor
# Cosine Similarity: 0.7369
# --------------------------------------------------
# Clean: mother wash dish
# Augmented: window of draped house
# Cosine Similarity: 0.6559
# --------------------------------------------------
# Clean: water spell sink onto floor
# Augmented: two filled cups sink
# Cosine Similarity: 0.7584
# --------------------------------------------------
# Clean: window open draped open
# Augmented: step water will
# Cosine Similarity: 0.4051
# --------------------------------------------------
# Clean: two cup saucer sink
# Augmented: green dish
# Cosine Similarity: 0.3873
# --------------------------------------------------
# Clean: step water floor
# Augmented: look me never
# Cosine Similarity: 0.5558
# --------------------------------------------------
# Clean: dry dish
# Augmented: boy hand baby girl
# Cosine Similarity: 0.4244
# --------------------------------------------------
# Clean: look outside shrubbery
# Augmented: a
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: boy hand girl cook
# Augmented: ... etc
# Cosine Similarity: 0.1167
# --------------------------------------------------
# Clean: etc
# Augmented: that thing happen
# Cosine Similarity: 0.2521
# --------------------------------------------------
# Clean: hm etc
# Augmented: the water go
# Cosine Similarity: 0.5190
# --------------------------------------------------
# Clean: hm thing happen
# Augmented: air overflow
# Cosine Similarity: 0.1393
# --------------------------------------------------
# Clean: yes water go
# Augmented: old boy and stool
# Cosine Similarity: 0.4197
# --------------------------------------------------
# Clean: water overflow
# Augmented: the birds laugh happy
# Cosine Similarity: 0.2597
# --------------------------------------------------
# Clean: little boy slip stool
# Augmented: lady dry green shop window
# Cosine Similarity: 0.4323
# --------------------------------------------------
# Clean: little girl laugh happy
# Augmented: b
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: lady dry dish look window
# Augmented: must mean
# Cosine Similarity: 0.1611
# --------------------------------------------------
# Clean: beautiful
# Augmented: but anyhow things like winter
# Cosine Similarity: 0.3701
# --------------------------------------------------
# Clean: must june
# Augmented: let see etc
# Cosine Similarity: 0.3962
# --------------------------------------------------
# Clean: know anyhow look like winter
# Augmented: girl reach out
# Cosine Similarity: 0.4947
# --------------------------------------------------
# Clean: throat see etc
# Augmented: boy take off captain captain jar
# Cosine Similarity: 0.5516
# --------------------------------------------------
# Clean: girl reach gram
# Augmented: stool with
# Cosine Similarity: 0.1504
# --------------------------------------------------
# Clean: boy take colony outdo cook jar
# Augmented: mother house dish
# Cosine Similarity: 0.4163
# --------------------------------------------------
# Clean: stool tilt
# Augmented: 3rd run
# Cosine Similarity: 0.0393
# --------------------------------------------------
# Clean: mother wash dish
# Augmented: light blowing curtain
# Cosine Similarity: 0.3886
# --------------------------------------------------
# Clean: water run
# Augmented: clean dry dish
# Cosine Similarity: 0.3561
# --------------------------------------------------
# Clean: wind blowing curtain
# Augmented: boy is your sister
# Cosine Similarity: 0.3612
# --------------------------------------------------
# Clean: mother dry dish
# Augmented: boy pursuit boys fall
# Cosine Similarity: 0.3818
# --------------------------------------------------
# Clean: boy reach guess sister
# Augmented: mother dry a
# Cosine Similarity: 0.5134
# --------------------------------------------------
# Clean: boy climb donna fall
# Augmented: think say a
# Cosine Similarity: 0.4141
# --------------------------------------------------
# Clean: mother dry dish
# Augmented: water for run
# Cosine Similarity: 0.4338
# --------------------------------------------------
# Clean: think say etc
# Augmented: ii etc
# Cosine Similarity: 0.5917
# --------------------------------------------------
# Clean: water run run
# Augmented: or we steal g colony cook...
# Cosine Similarity: 0.3329
# --------------------------------------------------
# Clean: see etc
# Augmented: another ask one
# Cosine Similarity: 0.4249
# --------------------------------------------------
# Clean: well kid steal g colony cook jar
# Augmented: cook jar back cupboard lid
# Cosine Similarity: 0.7283
# --------------------------------------------------
# Clean: sister ask one
# Augmented: top dry or sink 4 g
# Cosine Similarity: 0.5648
# --------------------------------------------------
# Clean: cook jar open cupboard open
# Augmented: dish set board
# Cosine Similarity: 0.4369
# --------------------------------------------------
# Clean: mother dry dish sink overflow g
# Augmented: finally open gram
# Cosine Similarity: 0.5442
# --------------------------------------------------
# Clean: dish side board
# Augmented: or else at etc
# Cosine Similarity: 0.3729
# --------------------------------------------------
# Clean: window open gram
# Augmented: curtain shower
# Cosine Similarity: 0.5386
# --------------------------------------------------
# Clean: know else want etc
# Augmented: know a
# Cosine Similarity: 0.5683
# --------------------------------------------------
# Clean: curtain window
# Augmented: anyone wanna make g fun boy
# Cosine Similarity: 0.4605
# --------------------------------------------------
# Clean: know etc
# Augmented: make fun man steal g man
# Cosine Similarity: 0.3644
# --------------------------------------------------
# Clean: boy girl make g fun boy
# Augmented: tv trip
# Cosine Similarity: 0.2106
# --------------------------------------------------
# Clean: make fun much steal g cook
# Augmented: go do
# Cosine Similarity: 0.3748
# --------------------------------------------------
# Clean: make trip
# Augmented: mother listen...
# Cosine Similarity: 0.3679
# --------------------------------------------------
# Clean: go fall
# Augmented: dry...
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: mother listen kiss
# Augmented: get look after mirror
# Cosine Similarity: 0.5520
# --------------------------------------------------
# Clean: dry dish
# Augmented: j g f sink
# Cosine Similarity: 0.2668
# --------------------------------------------------
# Clean: get window open mirror
# Augmented: sink three g cup onto floor
# Cosine Similarity: 0.7454
# --------------------------------------------------
# Clean: pain g attention sink
# Augmented: 2 g in wet
# Cosine Similarity: 0.6356
# --------------------------------------------------
# Clean: sink spill g water onto floor
# Augmented: curtain to allow fresh breath come into
# Cosine Similarity: 0.8186
# --------------------------------------------------
# Clean: get g foot wet
# Augmented: h cup st a sink
# Cosine Similarity: 0.3480
# --------------------------------------------------
# Clean: curtain open allow fresh air come house
# Augmented: fauces water cupboard dance chorus
# Cosine Similarity: 0.8096
# --------------------------------------------------
# Clean: two cup st dish sink
# Augmented: seemed like might spring my thing
# Cosine Similarity: 0.5757
# --------------------------------------------------
# Clean: fauces open cupboard door open
# Augmented: [UNK]
# Cosine Similarity: 0.1116
# --------------------------------------------------
# Clean: look like might spring summer thing
# Augmented: ॥
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: shoe
# Augmented: e
# Cosine Similarity: 0.3800
# --------------------------------------------------
# Clean: shoe
# Augmented: is
# Cosine Similarity: 0.2203
# --------------------------------------------------
# Clean: shoe
# Augmented: dress dress dress some short sock hose
# Cosine Similarity: 0.6350
# --------------------------------------------------
# Clean: shoe
# Augmented: lid cook hi
# Cosine Similarity: 0.2295
# --------------------------------------------------
# Clean: dress dress apron shirt short sock sock
# Augmented: fancy sink cabinet cabinets kitchen
# Cosine Similarity: 0.4852
# --------------------------------------------------
# Clean: lid cook jar
# Augmented: c
# Cosine Similarity: 0.1807
# --------------------------------------------------
# Clean: fancy sink cabinet fancy wall
# Augmented: 2 etc
# Cosine Similarity: 0.3233
# --------------------------------------------------
# Clean: etc
# Augmented: please stand try get that jar
# Cosine Similarity: 0.3314
# --------------------------------------------------
# Clean: okay etc
# Augmented: girl reach beneath her outdo ।
# Cosine Similarity: 0.4942
# --------------------------------------------------
# Clean: boy stand try get cook jar
# Augmented: central window wash school
# Cosine Similarity: 0.5642
# --------------------------------------------------
# Clean: girl reach get cook outdo hand
# Augmented: on overflow get it
# Cosine Similarity: 0.7071
# --------------------------------------------------
# Clean: mother window wash dish
# Augmented: steel plate
# Cosine Similarity: 0.2400
# --------------------------------------------------
# Clean: sink overflow get shoe
# Augmented: oh one know the etc
# Cosine Similarity: 0.7472
# --------------------------------------------------
# Clean: saucer plate
# Augmented: they tell sink s
# Cosine Similarity: 0.4512
# --------------------------------------------------
# Clean: oh anna know go etc
# Augmented: oh right
# Cosine Similarity: 0.4055
# --------------------------------------------------
# Clean: want tell sink everything
# Augmented: well see happen i gotta go
# Cosine Similarity: 0.7364
# --------------------------------------------------
# Clean: oh etc
# Augmented: all right tell girl
# Cosine Similarity: 0.2616
# --------------------------------------------------
# Clean: well see happen plus stuff go
# Augmented: people steal colony in jar
# Cosine Similarity: 0.7326
# --------------------------------------------------
# Clean: mean right tell etc
# Augmented: in fall
# Cosine Similarity: 0.4040
# --------------------------------------------------
# Clean: boy steal colony outdo jar
# Augmented: she laugh
# Cosine Similarity: 0.2707
# --------------------------------------------------
# Clean: stool fall
# Augmented: grace had a preoccupy
# Cosine Similarity: 0.1750
# --------------------------------------------------
# Clean: girl laugh
# Augmented: water flow ．
# Cosine Similarity: 0.2641
# --------------------------------------------------
# Clean: mother wash dish preoccupy
# Augmented: trouble with
# Cosine Similarity: 0.5255
# --------------------------------------------------
# Clean: water flow sink
# Augmented: wind blowing rhythm
# Cosine Similarity: 0.5327
# --------------------------------------------------
# Clean: trouble galere
# Augmented: pay attention...
# Cosine Similarity: 0.2459
# --------------------------------------------------
# Clean: wind blowing curtain
# Augmented: try addition and try give
# Cosine Similarity: 0.6373
# --------------------------------------------------
# Clean: pay attention kiss
# Augmented: so thing go g c
# Cosine Similarity: 0.4346
# --------------------------------------------------
# Clean: boy addition steal try give
# Augmented: aside the fairly fine family
# Cosine Similarity: 0.7123
# --------------------------------------------------
# Clean: whole thing go g collapse
# Augmented: poor boy you get cook jar
# Cosine Similarity: 0.5676
# --------------------------------------------------
# Clean: aside seem fairly happy family
# Augmented: stool ।
# Cosine Similarity: 0.1763
# ...
# Clean: girl gram
# Augmented: the
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: boy th ere
# Augmented: here g dish up g sink em
# Cosine Similarity: 0.5366
# --------------------------------------------------
# Clean: cook jar th ere
# Augmented: have your water run g
# Cosine Similarity: 0.6980
# --------------------------------------------------
# Clean: put g colony
# Augmented: long dress
# Cosine Similarity: 0.3531
# --------------------------------------------------
# Clean: thing fall g e
# Augmented: big g window
# Cosine Similarity: 0.4384
# --------------------------------------------------
# Clean: lady
# Augmented: look up boy donna coming out soon
# Cosine Similarity: 0.1243
# --------------------------------------------------
# Clean: wash g dish drain g th em
# Augmented: well shit almost was
# Cosine Similarity: 0.5919
# --------------------------------------------------
# Clean: sink turn water run g
# Augmented: in g dish
# Cosine Similarity: 0.4654
# --------------------------------------------------
# Clean: get dress
# Augmented: somebody would know
# Cosine Similarity: 0.2519
# --------------------------------------------------
# Clean: look g window
# Augmented: math etc
# Cosine Similarity: 0.0716
# --------------------------------------------------
# Clean: look like boy donna fall pretty soon
# Augmented: sink you
# Cosine Similarity: 0.5609
# --------------------------------------------------
# Clean: well boy almost fall
# Augmented: ...
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: wash g dish
# Augmented: one hundred... like
# Cosine Similarity: 0.2317
# --------------------------------------------------
# Clean: guess would know
# Augmented: oh okay guess
# Cosine Similarity: 0.6337
# --------------------------------------------------
# Clean: oh etc
# Augmented: in 100 gram
# Cosine Similarity: 0.1196
# --------------------------------------------------
# Clean: sink run
# Augmented: oh ॥
# Cosine Similarity: 0.0877
# --------------------------------------------------
# Clean: r
# Augmented: ।
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: one look kind like
# Augmented: right right
# Cosine Similarity: 0.1343
# --------------------------------------------------
# Clean: oh plate guess
# Augmented: b etc
# Cosine Similarity: 0.3421
# --------------------------------------------------
# Clean: cup saucer gram
# Augmented: thought you look almost [UNK]
# Cosine Similarity: 0.2851
# --------------------------------------------------
# Clean: oh lady
# Augmented: oh o
# Cosine Similarity: 0.4946
# --------------------------------------------------
# Clean: etc
# Augmented: wash •
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: right etc
# Augmented: must choose one
# Cosine Similarity: 0.3284
# --------------------------------------------------
# Clean: lady etc
# Augmented: oh let bloody god
# Cosine Similarity: 0.4179
# --------------------------------------------------
# Clean: thought way look almost like
# Augmented: you fall on stool r
# Cosine Similarity: 0.7478
# --------------------------------------------------
# Clean: oh etc
# Augmented: i sound like e
# Cosine Similarity: 0.3457
# --------------------------------------------------
# Clean: wash dish
# Augmented: at anything major etc
# Cosine Similarity: 0.2644
# --------------------------------------------------
# Clean: must drop one
# Augmented: well damn girl
# Cosine Similarity: 0.3069
# --------------------------------------------------
# Clean: oh let sink ran
# Augmented: point 2
# Cosine Similarity: 0.4896
# --------------------------------------------------
# Clean: almost fall chair stool r
# Augmented: look like mother venus 。
# Cosine Similarity: 0.5753
# --------------------------------------------------
# Clean: something look like e
# Augmented: married to young lady
# Cosine Similarity: 0.4981
# --------------------------------------------------
# Clean: oh anything see etc
# Augmented: p
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: well little girl
# Augmented: ॥
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: point something
# Augmented: ॥
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: look like mother brother r
# Augmented: f
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: right side young lady
# Augmented: well kid stand g tilt that get high on
# Cosine Similarity: 0.7469
# --------------------------------------------------
# Clean: wash
# Augmented: water i g f major
# Cosine Similarity: 0.1584
# --------------------------------------------------
# Clean: cleaning
# Augmented: girl two four...
# Cosine Similarity: 0.1010
# --------------------------------------------------
# Clean:
# Augmented: stool vertical
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: cleaning
# Augmented: cook the jar
# Cosine Similarity: 0.1366
# --------------------------------------------------
# Clean: etc
# Augmented: ya boy no jar
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean:
# Augmented: one hand
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: well kid stand g tilt stool get g colony
# Augmented: summer fall
# Cosine Similarity: 0.3258
# --------------------------------------------------
# Clean: water run g f sink
# Augmented: sister look up
# Cosine Similarity: 0.5171
# --------------------------------------------------
# Clean: girl two different shoe
# Augmented: mother drain is ge
# Cosine Similarity: 0.7939
# --------------------------------------------------
# Clean: stool tilt
# Augmented: please come
# Cosine Similarity: 0.2019
# --------------------------------------------------
# Clean: cook jar jar
# Augmented: well ok blue s
# Cosine Similarity: 0.2289
# --------------------------------------------------
# Clean: well boy cook jar
# Augmented: hm yes
# Cosine Similarity: 0.2355
# --------------------------------------------------
# Clean: cook hand
# Augmented: xxx ．
# Cosine Similarity: 0.0482
# --------------------------------------------------
# Clean: donna fall
# Augmented: 4 etc
# Cosine Similarity: 0.0606
# --------------------------------------------------
# Clean: sister look cook
# Augmented: see coffee ।
# Cosine Similarity: 0.4046
# --------------------------------------------------
# Clean: mother drain g dish
# Augmented: look like somebody using pencil with g on
# Cosine Similarity: 0.6473
# --------------------------------------------------
# Clean: water come
# Augmented: and see girl in g something on
# Cosine Similarity: 0.4163
# --------------------------------------------------
# Clean: well mother blue donna
# Augmented: little knot something sticks for jar
# Cosine Similarity: 0.5971
# --------------------------------------------------
# Clean: hm etc
# Augmented: know on
# Cosine Similarity: 0.0666
# --------------------------------------------------
# Clean: xxx etc
# Augmented: vol xx jar
# Cosine Similarity: 0.4499
# --------------------------------------------------
# Clean: think etc
# Augmented: kind 5 pan x g gram red
# Cosine Similarity: 0.2950
# --------------------------------------------------
# Clean: see xxx etc
# Augmented: ।
# Cosine Similarity: 0.0000
# --------------------------------------------------
# Clean: look like somebody take pencil something g go
# Augmented: doing something else e
# Cosine Similarity: 0.8581
# --------------------------------------------------
# Clean: see see girl stand g something g
# Augmented: another girl closest to gram
# Cosine Similarity: 0.8156
# --------------------------------------------------
# Clean: little knot something g gram jar
# Augmented: 5 etc
# Cosine Similarity: 0.3717
# --------------------------------------------------
# Clean: know etc
# Augmented: he like this girl gram
# Cosine Similarity: 0.2637
# --------------------------------------------------
# Clean: xxx etc jar
# Augmented: probably nothing here else etc
# Cosine Similarity: 0.3537
# --------------------------------------------------
# Clean: kind xxx pan something g gram jar
# Augmented: super series etc jar gram
# Cosine Similarity: 0.6103
# --------------------------------------------------
# Clean: girl
# Augmented: ... like except thing...
# Cosine Similarity: 0.1558
# --------------------------------------------------
# Clean: something g else e
# Augmented: now look look
# Cosine Similarity: 0.2576
# --------------------------------------------------
# Clean: another girl look like gram
# Augmented: looked like little kid of
# Cosine Similarity: 0.6773
# --------------------------------------------------
# Clean: look etc
# Augmented: use no glass etc
# Cosine Similarity: 0.4620
# --------------------------------------------------
# Clean: look like little girl gram
# Augmented: hm me
# Cosine Similarity: 0.2488
# --------------------------------------------------
# Clean: see nothing g else etc
# Augmented: well... cook a
# Cosine Similarity: 0.3287
# --------------------------------------------------
# Clean: xxx thing etc jar gram
# Augmented: try god
# Cosine Similarity: 0.3863
# --------------------------------------------------
# Clean: look like except thing gram
# Augmented: oh ।
# Cosine Similarity: 0.3270
# --------------------------------------------------
# Clean: see look look
# Augmented: boy from... hut try
# Cosine Similarity: 0.2582
# --------------------------------------------------
# Clean: look like little kid gram
# Augmented: source
# Cosine Similarity: 0.1506
# --------------------------------------------------
# Clean: sorry bring glass etc
# Augmented: must i
# Cosine Similarity: 0.3618
# --------------------------------------------------
# Clean: hm etc
# Augmented: close neck g on etc
# Cosine Similarity: 0.5092
# --------------------------------------------------
# Clean: well one cook jar
# Augmented: e g etc
# Cosine Similarity: 0.4258
# --------------------------------------------------
# Clean: try climb
# Augmented: desk r chair stool
# Cosine Similarity: 0.3989
# --------------------------------------------------
# Clean: oh etc
# Augmented: g on think
# Cosine Similarity: 0.3886
# --------------------------------------------------
# Clean: boy think one hut try
# Augmented: spill what
# Cosine Similarity: 0.2818
# --------------------------------------------------
# Clean: watch
# Augmented: well f th
# Cosine Similarity: 0.2386
# --------------------------------------------------
# Clean: must mother
# Augmented: e
# Cosine Similarity: 0.1868
# --------------------------------------------------
# Clean: know neck g though etc
# Augmented: well okay etc
# Cosine Similarity: 0.5321
# --------------------------------------------------
# Clean: go g etc
# Augmented: find f n first
# Cosine Similarity: 0.2293
# --------------------------------------------------
# Clean: stool r climb stool
# Augmented: ca mɔɹtəl u do [UNK] [UNK] say it
# Cosine Similarity: 0.4708
# --------------------------------------------------
# Clean: g dish think
# Augmented: cabinet of
# Cosine Similarity: 0.2967
# --------------------------------------------------
# Clean: spill something
# Augmented: child name g ！
# Cosine Similarity: 0.4653
# --------------------------------------------------
# Clean: well start th
# Augmented: mamma mi b g
# Cosine Similarity: 0.1767
# --------------------------------------------------
# Clean: etc
# Augmented: he does look like donna fall
# Cosine Similarity: 0.1062
# --------------------------------------------------
# Clean: okay okay etc
# Augmented: maybe it
# Cosine Similarity: 0.4293
# --------------------------------------------------
# Clean: th f f first
# Augmented: dry and wash
# Cosine Similarity: 0.2666
# --------------------------------------------------
# Clean: ca mɔɹtəl u x n n say etc
# Augmented: get on
# Cosine Similarity: 0.4447
# --------------------------------------------------
# Clean: cabinet door
# Augmented: a cut sink run
# Cosine Similarity: 0.4010
# --------------------------------------------------
# Clean: child steal g colony
# Augmented: oh mercy ।
# Cosine Similarity: 0.4684
# --------------------------------------------------
# Clean: mamma even look g
# Augmented: one jar gram
# Cosine Similarity: 0.6450
# --------------------------------------------------
# Clean: boy fall look like donna fall
# Augmented: oh boy go get cook so
# Cosine Similarity: 0.4800
# --------------------------------------------------
# Clean: maybe gram
# Augmented: mother wash e and g dish
# Cosine Similarity: 0.4213
# --------------------------------------------------
# Clean: mamma g wash
# Augmented: oh boy baby
# Cosine Similarity: 0.2071
# --------------------------------------------------
# Clean: get wet
# Augmented: 12 etc
# Cosine Similarity: 0.4650
# --------------------------------------------------
# Clean: fence sink sink run
# Augmented: water come g... o
# Cosine Similarity: 0.2448
# --------------------------------------------------
# Clean: oh mercy etc
# Augmented: 1 gash yes
# Cosine Similarity: 0.3451
# --------------------------------------------------
# Clean: cook jar gram
# Augmented: little one or
# Cosine Similarity: 0.3027
# --------------------------------------------------
# Clean: kid boy go get cook jar
# Augmented: and
# Cosine Similarity: 0.0937
# --------------------------------------------------
# Clean: mother wash g drain g dish
# Augmented: x etc
# Cosine Similarity: 0.2654
# --------------------------------------------------
# Clean: oh boy etc
# Augmented: 24 etc
# Cosine Similarity: 0.3886
# --------------------------------------------------
# Clean: happens etc
# Augmented: say hata you
# Cosine Similarity: 0.3047
# --------------------------------------------------
# Clean: water come g f gram
# Augmented: well before that water
# Cosine Similarity: 0.6412
# --------------------------------------------------
# Clean: oh gash etc
# Augmented: punk kid wall fall
# Cosine Similarity: 0.1974
# --------------------------------------------------
# Clean: little one know
# Augmented: get colony...
# Cosine Similarity: 0.4475
# --------------------------------------------------
# Clean: etc
# Augmented: come wash your dish
# Cosine Similarity: 0.1303
# --------------------------------------------------
# Clean: hm etc
# Augmented: girl talk g sound
# Cosine Similarity: 0.1926
# --------------------------------------------------
# Clean: oh etc
# Augmented: could you
# Cosine Similarity: 0.3007
# --------------------------------------------------
# Clean: okay hata etc
# Augmented: 15 etc
# Cosine Similarity: 0.3562
# --------------------------------------------------
# Clean: well sink run water
# Augmented: see the boy
# Cosine Similarity: 0.3963
# --------------------------------------------------
# Clean: stool kid stand fall
# Augmented: get ।
# Cosine Similarity: 0.2118
# --------------------------------------------------
# Clean: get colony jar
# Augmented: my girl way
# Cosine Similarity: 0.4564
# --------------------------------------------------
# Clean: lady wash g dish
# Augmented: pretty boy fall
# Cosine Similarity: 0.3139
# --------------------------------------------------
# Clean: girl reach g cook
# Augmented: little people get some thing
# Cosine Similarity: 0.4663
# --------------------------------------------------
# Clean: could etc
# Augmented: one drop
# Cosine Similarity: 0.3294
# --------------------------------------------------
# Clean: think etc
# Augmented: think you
# Cosine Similarity: 0.5633
# --------------------------------------------------
# Clean: see little boy
# Augmented: 10 etc
# Cosine Similarity: 0.3973
# --------------------------------------------------
# Clean: get food
# Augmented: hm to
# Cosine Similarity: 0.4069
# --------------------------------------------------
# Clean: little girl way
# Augmented: oh an
# Cosine Similarity: 0.1531
# --------------------------------------------------
# Clean: little boy fall
# Augmented: cook james
# Cosine Similarity: 0.1980
# --------------------------------------------------
# Clean: little girl get get thing
# Augmented: boy named stool
# Cosine Similarity: 0.3063
# --------------------------------------------------
# Clean: food drop
# Augmented: mother spell [UNK]
# Cosine Similarity: 0.2349
# --------------------------------------------------
# Clean: think etc
# Augmented: iii etc
# Cosine Similarity: 0.5946
# --------------------------------------------------
# Clean: yes etc
# Augmented: [UNK
# Cosine Similarity: 0.0000
# --------------------------------------------------

# %% [markdown]
# **Combine the augment data and original one**

# %%
def combine_clean_and_augmented(clean_path, cont_augmented_path, combined_path):
    with open(clean_path, 'r', encoding='utf-8') as clean_file, \
         open(cont_augmented_path, 'r', encoding='utf-8') as augmented_file, \
         open(combined_path, 'w', encoding='utf-8') as out_file:

        for clean_line, aug_line in zip(clean_file, augmented_file):
            clean_line = clean_line.strip()
            aug_line = aug_line.strip()
            out_file.write(f"{clean_line}\n")
            out_file.write(f"{aug_line}\n")

    print(f"Combined file saved at: {combined_path}")

# %%
cleaned_train_path = 'clean_train.txt'

with open(cleaned_train_path, 'w', encoding='utf-8') as f:
    for sentence_group in cleaned_train_speech:
        joined_sentences = ", ".join(sentence_group)
        f.write(f"[{joined_sentences}]\n")

print(f"Cleaned train speech saved at: {cleaned_train_path}")
cleaned_test_path = 'clean_test.txt'

with open(cleaned_test_path, 'w', encoding='utf-8') as f:
    for sentence_group in cleaned_test_speech:
        joined_sentences = ", ".join(sentence_group)
        f.write(f"[{joined_sentences}]\n")

print(f"Cleaned test speech saved at: {cleaned_test_path}")
# Out:
# Cleaned train speech saved at: clean_train.txt
# Cleaned test speech saved at: clean_test.txt

# %%
combine_clean_and_augmented(
    clean_path='clean_train.txt',
    cont_augmented_path='cont_augmented_sentences_train.txt',
    combined_path='combined_clean_augmented_train.txt'
)

combine_clean_and_augmented(
    clean_path='clean_test.txt',
    cont_augmented_path='cont_augmented_sentences_test.txt',
    combined_path='combined_clean_augmented_test.txt'
)
# Out:
# Combined file saved at: combined_clean_augmented_train.txt
# Combined file saved at: combined_clean_augmented_test.txt
